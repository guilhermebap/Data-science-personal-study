# %% [markdown]
# # Quarentena de dados - Aula 01
# ### Introdução

# %%
#importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filmes = pd.read_csv('datasets/movies.csv')
avaliacoes = pd.read_csv('datasets/ratings.csv')
filmes.columns = ['filmeId', 'titulo', 'generos']
avaliacoes.columns = ['usuarioId', 'filmeId', 'nota', 'momento']

# %%
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# ### Analise Exploratória de dados (EDA)

# %%
avaliacoes.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
filmes.shape
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
avaliacoes.query('filmeId == 1').mean()['nota']
# Out:
# 3.9209302325581397

# %%
avaliacoesMedia = avaliacoes.groupby('filmeId')['nota'].mean()
avaliacoesMedia.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
avaliacoesMedia.shape
# Out:
# (9724,)

# %%
filmesComMediaComNaN = filmes.join(avaliacoesMedia, on='filmeId', how='left')
filmesComMediaComNaN['notas'] = filmesComMediaComNaN.pop('nota')
filmesComMediaComNaN.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos     notas
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                   Adventure|Children|Fantasy  3.431818
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429

# %%
filmesComMediaComNaN.sort_values('notas', ascending=False)
# Out:
#       filmeId                                 titulo                generos  \
# 7656    88448  Paper Birds (Pájaros de papel) (2010)           Comedy|Drama
# 8107   100556             Act of Killing, The (2012)            Documentary
# 9083   143031                        Jump In! (2007)   Comedy|Drama|Romance
# 9094   143511                           Human (2015)            Documentary
# 9096   143559                    L.A. Slasher (2015)   Comedy|Crime|Fantasy
# ...       ...                                    ...                    ...
# 5749    30892     In the Realms of the Unreal (2004)  Animation|Documentary
# 5824    32160               Twentieth Century (1934)                 Comedy
# 5837    32371              Call Northside 777 (1948)  Crime|Drama|Film-Noir
# 5957    34482           Browning Version, The (1951)                  Drama
# 7565    85565                     Chalet Girl (2011)         Comedy|Romance
#
#       notas
# 7656    5.0
# 8107    5.0
# 9083    5.0
# 9094    5.0
# 9096    5.0
# ...     ...
# 5749    NaN
# 5824    NaN
# 5837    NaN
# 5957    NaN
# 7565    NaN
#
# [9742 rows x 4 columns]

# %%
filmesComMedia = filmes.join(avaliacoesMedia, on='filmeId', how='right')
filmesComMedia['notas'] = filmesComMedia.pop('nota')
filmesComMedia.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos     notas
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                   Adventure|Children|Fantasy  3.431818
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429

# %%
filmesComMedia.sort_values('notas', ascending=False)
# Out:
#       filmeId                                 titulo  \
# 7656    88448  Paper Birds (Pájaros de papel) (2010)
# 8107   100556             Act of Killing, The (2012)
# 9083   143031                        Jump In! (2007)
# 9094   143511                           Human (2015)
# 9096   143559                    L.A. Slasher (2015)
# ...       ...                                    ...
# 9271   157172  Wizards of the Lost Kingdom II (1989)
# 7553    85334           Hard Ticket to Hawaii (1987)
# 6503    53453   Starcrash (a.k.a. Star Crash) (1978)
# 5210     8494             Cincinnati Kid, The (1965)
# 7162    71810                     Legionnaire (1998)
#
#                               generos  notas
# 7656                     Comedy|Drama    5.0
# 8107                      Documentary    5.0
# 9083             Comedy|Drama|Romance    5.0
# 9094                      Documentary    5.0
# 9096             Comedy|Crime|Fantasy    5.0
# ...                               ...    ...
# 9271                   Action|Fantasy    0.5
# 7553                    Action|Comedy    0.5
# 6503  Action|Adventure|Fantasy|Sci-Fi    0.5
# 5210                            Drama    0.5
# 7162       Action|Adventure|Drama|War    0.5
#
# [9724 rows x 4 columns]

# %% [markdown]
# ## Desafio 1 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# O Paulo fez uma análise rápida e disse que tem 18 filmes sem avaliações, será que ele acertou?
#
# Determine quantos filmes não tem avaliações e quais são esses filmes.

# %%
filmesSemMedia = filmesComMediaComNaN[filmesComMediaComNaN['notas'].isna()].reset_index().drop('index', axis=1)

filmesSemMedia
# Out:
#     filmeId                                        titulo  \
# 0      1076                         Innocents, The (1961)
# 1      2939                                Niagara (1953)
# 2      3338                        For All Mankind (1989)
# 3      3456  Color of Paradise, The (Rang-e khoda) (1999)
# 4      4194                I Know Where I'm Going! (1945)
# 5      5721                            Chosen, The (1981)
# 6      6668   Road Home, The (Wo de fu qin mu qin) (1999)
# 7      6849                                Scrooge (1970)
# 8      7020                                  Proof (1991)
# 9      7792                     Parallax View, The (1974)
# 10     8765                      This Gun for Hire (1942)
# 11    25855                  Roaring Twenties, The (1939)
# 12    26085                   Mutiny on the Bounty (1962)
# 13    30892            In the Realms of the Unreal (2004)
# 14    32160                      Twentieth Century (1934)
# 15    32371                     Call Northside 777 (1948)
# 16    34482                  Browning Version, The (1951)
# 17    85565                            Chalet Girl (2011)
#
#                      generos  notas
# 0      Drama|Horror|Thriller    NaN
# 1             Drama|Thriller    NaN
# 2                Documentary    NaN
# 3                      Drama    NaN
# 4          Drama|Romance|War    NaN
# 5                      Drama    NaN
# 6              Drama|Romance    NaN
# 7      Drama|Fantasy|Musical    NaN
# 8       Comedy|Drama|Romance    NaN
# 9                   Thriller    NaN
# 10  Crime|Film-Noir|Thriller    NaN
# 11      Crime|Drama|Thriller    NaN
# 12   Adventure|Drama|Romance    NaN
# 13     Animation|Documentary    NaN
# 14                    Comedy    NaN
# 15     Crime|Drama|Film-Noir    NaN
# 16                     Drama    NaN
# 17            Comedy|Romance    NaN

# %%
len(filmesSemMedia)
# Out:
# 18

# %% [markdown]
# ## Desafio 2 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Mudar o nome da coluna nota do dataframe **filmes_com_media** para nota_média após o join.

# %%
filmesComMediaComNaN
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos     notas
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                      Adventure|Children|Fantasy  3.431818
# 2                                  Comedy|Romance  3.259615
# 3                            Comedy|Drama|Romance  2.357143
# 4                                          Comedy  3.071429
# ...                                           ...       ...
# 9737              Action|Animation|Comedy|Fantasy  4.000000
# 9738                     Animation|Comedy|Fantasy  3.500000
# 9739                                        Drama  3.500000
# 9740                             Action|Animation  3.500000
# 9741                                       Comedy  4.000000
#
# [9742 rows x 4 columns]

# %%
filmesComMediaComNaN.rename(columns={'notas': 'nota_média'}, inplace=True)
filmesComMediaComNaN
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos  nota_média
# 0     Adventure|Animation|Children|Comedy|Fantasy    3.920930
# 1                      Adventure|Children|Fantasy    3.431818
# 2                                  Comedy|Romance    3.259615
# 3                            Comedy|Drama|Romance    2.357143
# 4                                          Comedy    3.071429
# ...                                           ...         ...
# 9737              Action|Animation|Comedy|Fantasy    4.000000
# 9738                     Animation|Comedy|Fantasy    3.500000
# 9739                                        Drama    3.500000
# 9740                             Action|Animation    3.500000
# 9741                                       Comedy    4.000000
#
# [9742 rows x 4 columns]

# %% [markdown]
# ## Desafio 3 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.

# %%
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
avaliacoes2 = avaliacoes.groupby('filmeId').agg({'nota': 'mean', 'usuarioId': 'count'}).reset_index()
avaliacoes2.columns = ['filmeId', 'nota_média', 'n_de_avaliacoes']
avaliacoes2.head()
# Out:
#    filmeId  nota_média  n_de_avaliacoes
# 0        1    3.920930              215
# 1        2    3.431818              110
# 2        3    3.259615               52
# 3        4    2.357143                7
# 4        5    3.071429               49

# %%
filmes.shape
# Out:
# (9742, 3)

# %%
avaliacoesVotoMedia = filmes.merge(avaliacoes2, on='filmeId', how='left')
#filmesComMedia = filmes.join(avaliacoesMedia, on='filmeId', how='right')

avaliacoesVotoMedia.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos  nota_média  n_de_avaliacoes
# 0  Adventure|Animation|Children|Comedy|Fantasy    3.920930            215.0
# 1                   Adventure|Children|Fantasy    3.431818            110.0
# 2                               Comedy|Romance    3.259615             52.0
# 3                         Comedy|Drama|Romance    2.357143              7.0
# 4                                       Comedy    3.071429             49.0

# %% [markdown]
# ## Desafio 4 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
#
# Arredondar as médias (coluna de nota média) para duas casas decimais.

# %%
filmesComMedia.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos     notas
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                   Adventure|Children|Fantasy  3.431818
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429

# %%
filmesComMedia['notas'] = filmesComMedia['notas'].round(2)
filmesComMedia.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos  notas
# 0  Adventure|Animation|Children|Comedy|Fantasy   3.92
# 1                   Adventure|Children|Fantasy   3.43
# 2                               Comedy|Romance   3.26
# 3                         Comedy|Drama|Romance   2.36
# 4                                       Comedy   3.07

# %% [markdown]
# ## Desafio 5 do [Allan Spadini](https://twitter.com/allanspadini)
#
# Descobrir os generos dos filmes (quais são eles, únicos). (esse aqui o bicho pega)

# %%
filmes.groupby('generos').count().reset_index()[['generos']]
# Out:
#                                  generos
# 0                     (no genres listed)
# 1                                 Action
# 2                       Action|Adventure
# 3             Action|Adventure|Animation
# 4    Action|Adventure|Animation|Children
# ..                                   ...
# 946                      Sci-Fi|Thriller
# 947                 Sci-Fi|Thriller|IMAX
# 948                             Thriller
# 949                                  War
# 950                              Western
#
# [951 rows x 1 columns]

# %% [markdown]
# ## Desafio 6 da [Thais André](https://twitter.com/thais_tandre)
#
# Contar o número de aparições de cada genero.

# %%
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
generos = filmes.groupby('generos')[['titulo']].count().reset_index().sort_values('titulo', ascending=False)
generos.rename(columns={'titulo': 'n_titulos'}, inplace=True)

# %%
generos.head()
# Out:
#             generos  n_titulos
# 812           Drama       1053
# 634          Comedy        946
# 670    Comedy|Drama        435
# 732  Comedy|Romance        363
# 868   Drama|Romance        349

# %% [markdown]
# ## Desafio 7 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Plotar o gráfico de aparições de cada genero. Pode ser um gráfico de tipo igual a barra.

# %%
# %matplotlib inline 
plt.barh('generos', 'n_titulos', data=generos[generos['n_titulos']>= 75].sort_values('n_titulos', ascending=True))
plt.title('Número de filmes por gêneros')
plt.xlabel('Número de filmes')
plt.ylabel('Gêneros')
# Out:
# Text(0, 0.5, 'Gêneros')
