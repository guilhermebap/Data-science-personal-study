# %% [markdown]
# # Word2Vec: Treinamento de Word Embedding
#
# ## Objetivos
# * Aprenda como usar Spacy no pré-processamento de dados textuais, suas vantagens e desvantagens
# * Aprenda a configurar os Hiperparâmetros do modelo Word2Vec
# * Treine o seu modelo Word2Vec, usando o Gensim
# * Crie um classificador de texto usando o seu próprio modelo Word2Vec
# * Disponibilize o seu modelo em uma aplicação web
#
# link: https://cursos.alura.com.br/course/word2vec-treinamento-word-embedding

# %% [markdown]
# ## Importando as bibliotecas necessárias

# %%
! python -m spacy download pt_core_news_sm
# Out:
# Collecting pt_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.2.5/pt_core_news_sm-2.2.5.tar.gz (21.2 MB)
#      |████████████████████████████████| 21.2 MB 1.3 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from pt_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (57.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')

# %%
import numpy as np
import pandas as pd
import gensim
import spacy
import pt_core_news_sm
from gensim.models import Word2Vec
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from gensim.models.callbacks import CallbackAny2Vec

# %% [markdown]
# ## Carregando a base de dados

# %%
dados_treino = pd.read_csv('/content/drive/MyDrive/Alura cursos/Word2Vec/treino.csv')
dados_teste = pd.read_csv('/content/drive/MyDrive/Alura cursos/Word2Vec/teste.csv')

# %%
dados_treino.head()
# Out:
#                                                title  ...                                               link
# 0  Após polêmica, Marine Le Pen diz que abomina n...  ...  http://www1.folha.uol.com.br/mundo/2017/04/187...
# 1  Macron e Le Pen vão ao 2º turno na França, em ...  ...  http://www1.folha.uol.com.br/mundo/2017/04/187...
# 2  Apesar de larga vitória nas legislativas, Macr...  ...  http://www1.folha.uol.com.br/mundo/2017/06/189...
# 3  Governo antecipa balanço, e Alckmin anuncia qu...  ...  http://www1.folha.uol.com.br/cotidiano/2015/07...
# 4  Após queda em maio, a atividade econômica sobe...  ...  http://www1.folha.uol.com.br/mercado/2017/08/1...
#
# [5 rows x 6 columns]

# %%
dados_teste.head()
# Out:
#                                                title  ...                                               link
# 0                                     Grandes irmãos  ...  http://www1.folha.uol.com.br/colunas/ruycastro...
# 1  Haddad congela orçamento e suspende emendas de...  ...  http://www1.folha.uol.com.br/colunas/monicaber...
# 2  Proposta de reforma da Fifa tem a divulgação d...  ...  http://www1.folha.uol.com.br/esporte/2015/09/1...
# 3  Mercado incipiente, internet das coisas conect...  ...  http://www1.folha.uol.com.br/mercado/2016/09/1...
# 4  Mortes: Psicanalista, estudou o autismo em cri...  ...  http://www1.folha.uol.com.br/cotidiano/2017/07...
#
# [5 rows x 6 columns]

# %%
print(f'Os dados de treino possuem {dados_treino.shape[0]} observações e {dados_treino.shape[1]} atributos')
print(f'Os dados de treino possuem {dados_teste.shape[0]} observações e {dados_teste.shape[1]} atributos')
# Out:
# Os dados de treino possuem 90000 observações e 6 atributos
# Os dados de treino possuem 20513 observações e 6 atributos

# %%
nlp = pt_core_news_sm.load()

# %%
nlp

# %%
texto = 'Rio de Janeiro é uma cidade maravilhosa'
doc = nlp(texto)
doc
# Out:
# Rio de Janeiro é uma cidade maravilhosa

# %%
textos_para_tratamento = (titulos.lower() for titulos in dados_treino.title)
textos_para_tratamento
# Out:
# <generator object <genexpr> at 0x7ff257a6c4d0>

# %%
def trata_textos(doc):
  tokens_validos = []
  for token in doc:
    e_valido = not token.is_stop and token.is_alpha
    if e_valido:
      tokens_validos.append(token.text)
    
  if len(tokens_validos) > 2:
    return " ".join(tokens_validos)

# %%
texto = 'Rio de 5845116 Janeiro é uma cidade!!!! maravilhosa'
doc = nlp(texto)

trata_textos(doc)
# Out:
# 'Rio Janeiro cidade maravilhosa'

# %%
import time
t0 = time.time()
textos_tratados = [trata_textos(doc) for doc in nlp.pipe(textos_para_tratamento, 
                                                        batch_size=1000, 
                                                        n_process=-1)]

t1= time.time()
print(t1-t0)
# Out:
# 219.23638200759888

# %%
titulos_tratados = pd.DataFrame({'title': textos_tratados})
titulos_tratados.head()
# Out:
#                                                title
# 0  polêmica marine le pen abomina negacionistas h...
# 1  macron e le pen a o turno frança revés siglas ...
# 2  apesar larga vitória legislativas macron terá ...
# 3  governo antecipa balanço e alckmin anuncia que...
# 4     queda maio a atividade econômica sobe junho bc

# %% [markdown]
# ## Inicando a fase de treinamento do modelo
#
# Utilizamos a biblioteca gensim que traz uma arquitetura implementada do Word2vec, onde precisamos apenas setar os parâmetros de configuração da nossa rede.

# %%
w2v_modelo

# %%
print(len(titulos_tratados))

titulos_tratados.dropna(inplace=True)
titulos_tratados.drop_duplicates(inplace=True)

print(len(titulos_tratados))
# Out:
# 86113
# 86113

# %%
lista_lista_tokens = [titulo.split( ) for titulo in titulos_tratados.title]

# %% [markdown]
# ### Treinando o modelo CBOW

# %%
import logging

#logging.basicConfig(format='%(asctime)s: -  %(message)s', level=logging.INFO)

w2v_modelo = Word2Vec(sg=0,
                      window=2,
                      size=300,
                      min_count=5,
                      alpha=0.03,
                      min_alpha=0.007)

w2v_modelo.build_vocab(lista_lista_tokens, progress_per=5000)
# Out:
# 2021-08-10 01:46:27,923: -  collecting all words and their counts
# 2021-08-10 01:46:27,931: -  PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-08-10 01:46:27,953: -  PROGRESS: at sentence #10000, processed 69298 words, keeping 14909 word types
# 2021-08-10 01:46:27,982: -  PROGRESS: at sentence #20000, processed 138620 words, keeping 20969 word types
# 2021-08-10 01:46:28,012: -  PROGRESS: at sentence #30000, processed 207976 words, keeping 25453 word types
# 2021-08-10 01:46:28,040: -  PROGRESS: at sentence #40000, processed 277254 words, keeping 28992 word types
# 2021-08-10 01:46:28,068: -  PROGRESS: at sentence #50000, processed 346641 words, keeping 31924 word types
# 2021-08-10 01:46:28,095: -  PROGRESS: at sentence #60000, processed 416318 words, keeping 34458 word types
# 2021-08-10 01:46:28,122: -  PROGRESS: at sentence #70000, processed 485882 words, keeping 36651 word types
# 2021-08-10 01:46:28,150: -  PROGRESS: at sentence #80000, processed 555521 words, keeping 38741 word types
# 2021-08-10 01:46:28,168: -  collected 39968 word types from a corpus of 597929 raw words and 86113 sentences
# 2021-08-10 01:46:28,170: -  Loading a fresh vocabulary
# 2021-08-10 01:46:28,212: -  effective_min_count=5 retains 13006 unique words (32% of original 39968, drops 26962)
# 2021-08-10 01:46:28,215: -  effective_min_count=5 leaves 552614 word corpus (92% of original 597929, drops 45315)
# 2021-08-10 01:46:28,268: -  deleting the raw counts dictionary of 39968 items
# 2021-08-10 01:46:28,272: -  sample=0.001 downsamples 11 most-common words
# 2021-08-10 01:46:28,275: -  downsampling leaves estimated 502900 word corpus (91.0% of prior 552614)
# 2021-08-10 01:46:28,326: -  estimated required memory for 13006 words and 300 dimensions: 37717400 bytes
# 2021-08-10 01:46:28,327: -  resetting layer weights

# %%
dir(w2v_modelo)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_check_input_data_sanity',
#  '_check_training_sanity',
#  '_clear_post_train',
#  '_do_train_epoch',
#  '_do_train_job',
#  '_get_job_params',
#  '_get_thread_working_mem',
#  '_job_producer',
#  '_load_specials',
#  '_log_epoch_end',
#  '_log_epoch_progress',
#  '_log_progress',
#  '_log_train_end',
#  '_minimize_model',
#  '_raw_word_count',
#  '_save_specials',
#  '_set_train_params',
#  '_smart_save',
#  '_train_epoch',
#  '_train_epoch_corpusfile',
#  '_update_job_params',
#  '_worker_loop',
#  '_worker_loop_corpusfile',
#  'accuracy',
#  'alpha',
#  'batch_words',
#  'build_vocab',
#  'build_vocab_from_freq',
#  'callbacks',
#  'cbow_mean',
#  'clear_sims',
#  'compute_loss',
#  'corpus_count',
#  'corpus_total_words',
#  'cum_table',
#  'delete_temporary_training_data',
#  'doesnt_match',
#  'epochs',
#  'estimate_memory',
#  'evaluate_word_pairs',
#  'get_latest_training_loss',
#  'hashfxn',
#  'hs',
#  'init_sims',
#  'intersect_word2vec_format',
#  'iter',
#  'layer1_size',
#  'load',
#  'load_word2vec_format',
#  'log_accuracy',
#  'max_final_vocab',
#  'min_alpha',
#  'min_alpha_yet_reached',
#  'min_count',
#  'model_trimmed_post_training',
#  'most_similar',
#  'most_similar_cosmul',
#  'n_similarity',
#  'negative',
#  'ns_exponent',
#  'predict_output_word',
#  'random',
#  'reset_from',
#  'running_training_loss',
#  'sample',
#  'save',
#  'save_word2vec_format',
#  'score',
#  'sg',
#  'similar_by_vector',
#  'similar_by_word',
#  'similarity',
#  'syn0_lockf',
#  'syn1',
#  'syn1neg',
#  'total_train_time',
#  'train',
#  'train_count',
#  'trainables',
#  'vector_size',
#  'vocabulary',
#  'window',
#  'wmdistance',
#  'workers',
#  'wv']

# %%
w2v_modelo.corpus_count
# Out:
# 86113

# %%
# iniciando a chamada callback
class callback(CallbackAny2Vec):
  def __init__(self):
    self.epoch = 0

def on_epoch_end(self, model):
  loss = model.get_latest_training_loss()
  if self.epoch == 0:
    print('Loss após a época {}: {}'.format(self.epoch, loss))
  else:
    print('Loss após a época {}: {}'.format(self.epoch, loss- self.loss_previous_step))
  self.epoch += 1
  self.loss_previous_step = loss

# %%
w2v_modelo.train(lista_lista_tokens, total_examples=w2v_modelo.corpus_count,
                 epochs=30,
                 compute_loss=True,
                 callbacks=[callback()])
# Out:
# 2021-08-10 01:47:03,947: -  training model with 3 workers on 13006 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=2
# 2021-08-10 01:47:04,975: -  EPOCH 1 - PROGRESS: at 66.94% examples, 330831 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47
-  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:40,082: -  EPOCH - 25 : training on 597929 raw words (503044 effective words) took 1.4s, 365415 effective words/s
# 2021-08-10 01:47:41,131: -  EPOCH 26 - PROGRESS: at 68.60% examples, 333683 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47:41,503: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 01:47:41,520: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 01:47:41,526: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:41,527: -  EPOCH - 26 : training on 597929 raw words (502706 effective words) took 1.4s, 351681 effective words/s
# 2021-08-10 01:47:42,555: -  EPOCH 27 - PROGRESS: at 70.26% examples, 347871 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47:42,920: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 01:47:42,928: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 01:47:42,946: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:42,947: -  EPOCH - 27 : training on 597929 raw words (503058 effective words) took 1.4s, 357491 effective words/s
# 2021-08-10 01:47:43,967: -  EPOCH 28 - PROGRESS: at 68.60% examples, 342654 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47:44,329: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 01:47:44,348: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 01:47:44,352: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:44,353: -  EPOCH - 28 : training on 597929 raw words (502839 effective words) took 1.4s, 361225 effective words/s
# 2021-08-10 01:47:45,374: -  EPOCH 29 - PROGRESS: at 70.26% examples, 351141 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47:45,737: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 01:47:45,742: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 01:47:45,751: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:45,752: -  EPOCH - 29 : training on 597929 raw words (502949 effective words) took 1.4s, 363487 effective words/s
# 2021-08-10 01:47:46,800: -  EPOCH 30 - PROGRESS: at 70.26% examples, 341744 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 01:47:47,161: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 01:47:47,163: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 01:47:47,184: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 01:47:47,186: -  EPOCH - 30 : training on 597929 raw words (502945 effective words) took 1.4s, 354309 effective words/s
# 2021-08-10 01:47:47,187: -  training on a 17937870 raw words (15086746 effective words) took 43.2s, 348920 effective words/s
# (15086746, 17937870)

# %%
w2v_modelo.wv.most_similar('google')
# Out:
# 2021-08-10 01:52:02,705: -  precomputing L2-norms of word weight vectors
# [('apple', 0.582836389541626),
#  ('facebook', 0.5689347982406616),
#  ('uber', 0.4988063871860504),
#  ('amazon', 0.4805878698825836),
#  ('waze', 0.4691309928894043),
#  ('software', 0.46819931268692017),
#  ('airbnb', 0.4672732353210449),
#  ('fbi', 0.46390458941459656),
#  ('walmart', 0.4373021721839905),
#  ('apps', 0.4366353750228882)]

# %%
w2v_modelo.wv.most_similar('microsoft')
# Out:
# [('unilever', 0.5961178541183472),
#  ('walmart', 0.5732885003089905),
#  ('lego', 0.5488518476486206),
#  ('tesla', 0.5473916530609131),
#  ('amazon', 0.5462477207183838),
#  ('inbev', 0.5434845089912415),
#  ('spotify', 0.5265981554985046),
#  ('sony', 0.5204979181289673),
#  ('chrysler', 0.512848973274231),
#  ('braskem', 0.5043861865997314)]

# %%
w2v_modelo.wv.most_similar('neymar')
# Out:
# [('messi', 0.5437285900115967),
#  ('benzema', 0.48244208097457886),
#  ('barça', 0.47397497296333313),
#  ('valdivia', 0.45517486333847046),
#  ('ibrahimovic', 0.45389801263809204),
#  ('suárez', 0.44436556100845337),
#  ('romário', 0.44328829646110535),
#  ('fred', 0.4385612905025482),
#  ('cristiano', 0.4366806149482727),
#  ('stjd', 0.4346413314342499)]

# %%
w2v_modelo.wv.most_similar('gm')
# Out:
# [('chrysler', 0.6733736991882324),
#  ('honda', 0.6651701927185059),
#  ('volks', 0.6548870205879211),
#  ('inbev', 0.6405227184295654),
#  ('embraer', 0.6281988024711609),
#  ('volkswagen', 0.6216104030609131),
#  ('renault', 0.6114151477813721),
#  ('toyota', 0.6049923896789551),
#  ('braskem', 0.6047013998031616),
#  ('csn', 0.5865892171859741)]

# %% [markdown]
# ### Treinando o modelo Skip-Gram

# %%
w2v_modelo_sg = Word2Vec(sg=1,
                         window=5,
                         size=300,
                         min_count=5,
                         alpha=0.03,
                         min_alpha=0.007)

w2v_modelo_sg.build_vocab(lista_lista_tokens, progress_per=5000)

w2v_modelo_sg.train(lista_lista_tokens, total_examples=w2v_modelo_sg.corpus_count,
                 epochs=30,
                 compute_loss=True,
                 callbacks=[callback()])
# Out:
# 2021-08-10 02:01:43,054: -  collecting all words and their counts
# 2021-08-10 02:01:43,059: -  PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-08-10 02:01:43,076: -  PROGRESS: at sentence #5000, processed 34716 words, keeping 10129 word types
# 2021-08-10 02:01:43,091: -  PROGRESS: at sentence #10000, processed 69298 words, keeping 14909 word types
# 2021-08-10 02:01:43,108: -  PROGRESS: at sentence #15000, processed 103841 words, keeping 18223 word types
# 2021-08-10 02:01:43,125: -  PROGRESS: at sentence #20000, processed 138620 words, keeping 20969 word types
# 2021-08-10 02:01:43,142: -  PROGRESS: at sentence #25000, processed 173257 words, keeping 23410 word types
# 2021-08-10 02:01:43,159: -  PROGRESS: at sentence #30000, processed 207976 words, keeping 25453 word types
# 2021-08-10 02:01:43,172: -  PROGRESS: at sentence #35000, processed 242567 words, keeping 27263 word types
# 2021-08-10 02:01:43,195: -  PROGRESS: at sentence #40000, processed 277254 words, keeping 28992 word types
# 2021-08-10 02:01:43,215: -  PROGRESS: at sentence #45000, processed 311910 words, keeping 30561 word types
# 2021-08-10 02:01:43,231: -  PROGRESS: at sentence #50000, processed 346641 words, keeping 31924 word types
# 2021-08-10 02:01:43,255: -  PROGRESS: at sentence #55000, processed 381564 words, keeping 33224 word types
# 2021-08-10 02:01:43,274: -  PROGRESS: at sentence #60000, processed 416318 words, keeping 34458 word types
# 2021-08-10 02:01:43,306: -  PROGRESS: at sentence #65000, processed 451172 words, keeping 35585 word types
# 2021-08-10 02:01:43,329: -  PROGRESS: at sentence #70000, processed 485882 words, keeping 36651 word types
# 2021-08-10 02:01:43,349: -  PROGRESS: at sentence #75000, processed 520667 words, keeping 37767 word types
# 2021-08-10 02:01:43,373: -  PROGRESS: at sentence #80000, processed 555521 words, keeping 38741 word types
# 2021-08-10 02:01:43,390: -  PROGRESS: at sentence #85000, processed 590198 words, keeping 39739 word types
# 2021-08-10 02:01:43,399: -  collected 39968 word types from a corpus of 597929 raw words and 86113 sentences
# 2021-08-10 02:01:43,405: -  Loading a fresh vocabulary
# 2021-08-10 02:01:43,457: -  effective_min_count=5 retains 13006 unique words (32% of original 39968, drops 26962)
# 2021-08-10 02:01:43,458: -  effective_min_count=5 leaves 552614 word corpus (92% of original 597929, drops 45315)
# 2021-08-10 02:01:43,515: -  deleting the raw counts dictionary of 39968 items
# 2021-08-10 02:01:43,519: -  sample=0.001 downsamples 11 most-common words
# 2021-08-10 02:01:43,523: -  downsampling leaves estimated 502900 word corpus (91.0% of prior 552614)
# 2021-08-10 02:01:43,582: -  estimated required memory for 13006 words and 300 dimensions: 37717400 bytes
# 2021-08-10 02:01:43,584: -  resetting layer weights
# 2021-08-10 02:01:46,512: -  training model with 3 workers on 13006 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window
words/s, in_qsize 5, out_qsize 0
# 2021-08-10 02:03:40,248: -  EPOCH 30 - PROGRESS: at 81.96% examples, 133222 words/s, in_qsize 5, out_qsize 0
# 2021-08-10 02:03:40,734: -  worker thread finished; awaiting finish of 2 more threads
# 2021-08-10 02:03:40,799: -  worker thread finished; awaiting finish of 1 more threads
# 2021-08-10 02:03:40,826: -  worker thread finished; awaiting finish of 0 more threads
# 2021-08-10 02:03:40,828: -  EPOCH - 30 : training on 597929 raw words (502977 effective words) took 3.7s, 136963 effective words/s
# 2021-08-10 02:03:40,829: -  training on a 17937870 raw words (15088743 effective words) took 114.3s, 131992 effective words/s
# (15088743, 17937870)

# %%
w2v_modelo_sg.wv.most_similar('google')
# Out:
# 2021-08-10 02:03:40,841: -  precomputing L2-norms of word weight vectors
# [('reguladores', 0.4206386208534241),
#  ('apple', 0.3930903673171997),
#  ('waze', 0.3882356882095337),
#  ('facebook', 0.3861532211303711),
#  ('concorda', 0.3793504238128662),
#  ('patentes', 0.36988765001296997),
#  ('android', 0.3693094551563263),
#  ('yahoo', 0.365840882062912),
#  ('buffett', 0.3651365637779236),
#  ('anúncios', 0.36011892557144165)]

# %%
w2v_modelo_sg.wv.most_similar('microsoft')
# Out:
# [('linkedin', 0.5354049801826477),
#  ('chips', 0.48254701495170593),
#  ('software', 0.47764453291893005),
#  ('bitcoin', 0.45045530796051025),
#  ('fertilizantes', 0.45014694333076477),
#  ('verizon', 0.44941723346710205),
#  ('investindo', 0.43623656034469604),
#  ('fabricar', 0.4343263506889343),
#  ('silício', 0.42991238832473755),
#  ('syngenta', 0.42629486322402954)]

# %%
w2v_modelo_sg.wv.most_similar('neymar')
# Out:
# [('barça', 0.518221914768219),
#  ('suárez', 0.4742594361305237),
#  ('cavani', 0.4607198238372803),
#  ('messi', 0.45851776003837585),
#  ('benzema', 0.42924392223358154),
#  ('villarreal', 0.4286305606365204),
#  ('psg', 0.42676663398742676),
#  ('dedada', 0.4090576171875),
#  ('barcelona', 0.406423419713974),
#  ('fernandinho', 0.3941882848739624)]

# %%
w2v_modelo_sg.wv.most_similar('gm')
# Out:
# [('metalúrgicos', 0.5739935636520386),
#  ('motors', 0.5112147331237793),
#  ('honda', 0.5084389448165894),
#  ('airbags', 0.4985079765319824),
#  ('coletivas', 0.487079918384552),
#  ('cubatão', 0.48182615637779236),
#  ('audi', 0.47662973403930664),
#  ('bmw', 0.4720497727394104),
#  ('compartilhamento', 0.4632718563079834),
#  ('fiat', 0.4593982994556427)]

# %%
w2v_modelo_sg.wv.most_similar('galo')
# Out:
# [('lilly', 0.5294711589813232),
#  ('frevo', 0.5282864570617676),
#  ('beth', 0.5243561863899231),
#  ('cores', 0.523779571056366),
#  ('martinho', 0.5148050785064697),
#  ('sarti', 0.5133844017982483),
#  ('baralho', 0.4886307716369629),
#  ('sambista', 0.4788205921649933),
#  ('sereia', 0.4756861925125122),
#  ('foliões', 0.4724130928516388)]

# %%
w2v_modelo.wv.save_word2vec_format('/content/drive/MyDrive/Alura cursos/Word2Vec/modelo_cbow.txt', binary=False)
w2v_modelo_sg.wv.save_word2vec_format('/content/drive/MyDrive/Alura cursos/Word2Vec/modelo_skip.txt', binary=False)
# Out:
# 2021-08-10 02:03:40,970: -  storing 13006x300 projection weights into /content/drive/MyDrive/Alura cursos/Word2Vec/modelo_cbow.txt
# 2021-08-10 02:03:44,119: -  storing 13006x300 projection weights into /content/drive/MyDrive/Alura cursos/Word2Vec/modelo_skip.txt
