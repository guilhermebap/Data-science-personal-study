# %% [markdown]
# # Alura
# # Curso: Data Science: análises para saúde e medicina
#
# link: https://cursos.alura.com.br/course/data-science-saude-e-medicina

# %% [markdown]
# ### Importando as bibliotecas e os dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/11/21  6/12/21  6/13/21  \
# 0        0        0        0        0  ...    87716    88740    89861
# 1        0        0        0        0  ...   132437   132449   132459
# 2        0        0        0        0  ...   132727   133070   133388
# 3        0        0        0        0  ...    13813    13813    13813
# 4        0        0        0        0  ...    36455    36600    36705
#
#    6/14/21  6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21
# 0    91458    93272    93288    96531    98734    98734    98734
# 1   132461   132469   132476   132481   132484   132488   132490
# 2   133742   134115   134458   134840   135219   135586   135821
# 3    13826    13828    13836    13839    13842    13842    13842
# 4    36790    36921    37094    37289    37467    37604    37678
#
# [5 rows x 520 columns]

# %%
# Como alguns países separaram os dados de covid por regiões e outros não, esses dados estão errados, para resolver isso
# agruparemos esses dados por países
confirmed['Country/Region'].value_counts()
# Out:
# China             34
# Canada            16
# France            12
# United Kingdom    12
# Australia          8
#                   ..
# Egypt              1
# Somalia            1
# Jordan             1
# Holy See           1
# Sweden             1
# Name: Country/Region, Length: 194, dtype: int64

# %%
confirmed_by_country = confirmed.groupby('Country/Region').sum()
confirmed_by_country.head()
# Out:
#                      Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan     33.93911  67.709953        0        0        0        0
# Albania         41.15330  20.168300        0        0        0        0
# Algeria         28.03390   1.659600        0        0        0        0
# Andorra         42.50630   1.521800        0        0        0        0
# Angola         -11.20270  17.873900        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  6/11/21  6/12/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    87716    88740
# Albania               0        0        0        0  ...   132437   132449
# Algeria               0        0        0        0  ...   132727   133070
# Andorra               0        0        0        0  ...    13813    13813
# Angola                0        0        0        0  ...    36455    36600
#
#                 6/13/21  6/14/21  6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  \
# Country/Region
# Afghanistan       89861    91458    93272    93288    96531    98734    98734
# Albania          132459   132461   132469   132476   132481   132484   132488
# Algeria          133388   133742   134115   134458   134840   135219   135586
# Andorra           13813    13826    13828    13836    13839    13842    13842
# Angola            36705    36790    36921    37094    37289    37467    37604
#
#                 6/20/21
# Country/Region
# Afghanistan       98734
# Albania          132490
# Algeria          135821
# Andorra           13842
# Angola            37678
#
# [5 rows x 518 columns]

# %%
last_date = confirmed_by_country.columns[-1]
confirmed_by_country[last_date]
# Out:
# Country/Region
# Afghanistan            98734
# Albania               132490
# Algeria               135821
# Andorra                13842
# Angola                 37678
#                        ...
# Vietnam                13258
# West Bank and Gaza    312673
# Yemen                   6885
# Zambia                129033
# Zimbabwe               41779
# Name: 6/20/21, Length: 194, dtype: int64

# %%
confirmed_by_country.shape
# Out:
# (194, 518)

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
# ax.set_ylim([0, 20000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
# ax.set_ylim([0, 20000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(26,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:30].plot()
ax.set_ylim([0, 80000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:30].plot()
ax.set_ylim([20000, 60000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].plot()
plt.show()

# %%
confirmed_by_country.loc['Brazil'][2:].diff().tail(20)
# Out:
# 6/1/21     78926.0
# 6/2/21     95601.0
# 6/3/21     83391.0
# 6/4/21     37936.0
# 6/5/21     66017.0
# 6/6/21     39637.0
# 6/7/21     37156.0
# 6/8/21     52911.0
# 6/9/21     85748.0
# 6/10/21    88092.0
# 6/11/21    85149.0
# 6/12/21    78700.0
# 6/13/21    37948.0
# 6/14/21    39846.0
# 6/15/21    80609.0
# 6/16/21    95367.0
# 6/17/21    74042.0
# 6/18/21    98832.0
# 6/19/21    82288.0
# 6/20/21    44178.0
# Name: Brazil, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Diferença de casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().plot()
plt.show()

# %%
confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().dropna()
# Out:
# 1/29/20        0.000000
# 1/30/20        0.000000
# 1/31/20        0.000000
# 2/1/20         0.000000
# 2/2/20         0.000000
#                ...
# 6/16/21    72244.428571
# 6/17/21    70237.285714
# 6/18/21    72192.000000
# 6/19/21    72704.571429
# 6/20/21    73594.571429
# Name: Brazil, Length: 509, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Média movel dos casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().dropna().plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Confirmados por país', fontsize=18)

confirmed_by_country[last_date].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Confirmados por país', fontsize=18)

confirmed_by_country[last_date].sort_values(ascending=False)[0:10].plot(kind='bar')
plt.show()

# %%
display(deaths.head())
display(recovered.head())
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/11/21  6/12/21  6/13/21  \
# 0        0        0        0        0  ...     3412     3449     3527
# 1        0        0        0        0  ...     2453     2453     2453
# 2        0        0        0        0  ...     3560     3565     3571
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      819      825      831
#
#    6/14/21  6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21
# 0     3612     3683     3683     3842     3934     3934     3934
# 1     2453     2454     2454     2454     2454     2454     2454
# 2     3579     3588     3598     3605     3615     3624     3631
# 3      127      127      127      127      127      127      127
# 4      836      842      847      851      853      856      859
#
# [5 rows x 520 columns]
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/11/21  6/12/21  6/13/21  \
# 0        0        0        0        0  ...    60598    60939    61410
# 1        0        0        0        0  ...   129807   129826   129842
# 2        0        0        0        0  ...    92384    92620    92852
# 3        0        0        0        0  ...    13591    13591    13591
# 4        0        0        0        0  ...    30101    30207    30282
#
#    6/14/21  6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21
# 0    61706    61820    62397    62698    63426    63875    64401
# 1   129865   129879   129888   129895   129903   129910   129918
# 2    93094    93355    93586    93831    94093    94336    94571
# 3    13618    13626    13633    13640    13650    13650    13650
# 4    30359    30775    31003    31105    31569    31589    31676
#
# [5 rows x 520 columns]

# %%
def lastest_by_country(data):
    return data.groupby('Country/Region').sum().iloc[:, -1]

# %%
lastest_by_country(confirmed).head()
# Out:
# Country/Region
# Afghanistan     98734
# Albania        132490
# Algeria        135821
# Andorra         13842
# Angola          37678
# Name: 6/20/21, dtype: int64

# %%
informations = [lastest_by_country(confirmed), lastest_by_country(deaths), lastest_by_country(recovered)]

# %%
combined = pd.concat(informations, axis=1)
combined.columns = ['confirmed', 'deaths', 'recovered']
combined
# Out:
#                     confirmed  deaths  recovered
# Country/Region
# Afghanistan             98734    3934      64401
# Albania                132490    2454     129918
# Algeria                135821    3631      94571
# Andorra                 13842     127      13650
# Angola                  37678     859      31676
# ...                       ...     ...        ...
# Vietnam                 13258      66       5229
# West Bank and Gaza     312673    3551     306240
# Yemen                    6885    1355       3953
# Zambia                 129033    1644     108960
# Zimbabwe                41779    1672      37184
#
# [194 rows x 3 columns]

# %%
sum_up = combined.sum()
letality_rate = sum_up['deaths'] / sum_up['confirmed']
print(f'A taxa de letalidade no conjunto de dados é: {letality_rate:0.2%}')
# Out:
# A taxa de letalidade no conjunto de dados é: 2.17%

# %%
letality = combined.apply(lambda x: x['deaths']/x['confirmed'], axis=1)
letality.sort_values(ascending=False)[:20]
# Out:
# Country/Region
# Vanuatu                   0.250000
# MS Zaandam                0.222222
# Yemen                     0.196805
# Peru                      0.093847
# Mexico                    0.093323
# Sudan                     0.075302
# Syria                     0.073453
# Egypt                     0.057193
# Somalia                   0.052182
# Ecuador                   0.047695
# Bosnia and Herzegovina    0.047018
# China                     0.046802
# Bulgaria                  0.042728
# Tanzania                  0.041257
# Zimbabwe                  0.040020
# Afghanistan               0.039844
# Taiwan*                   0.039200
# Bolivia                   0.038223
# Comoros                   0.037359
# Hungary                   0.037093
# dtype: float64
