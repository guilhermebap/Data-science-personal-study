# %% [markdown]
# # Alura
# # Curso: Data Science: análises para saúde e medicina
#
# link: https://cursos.alura.com.br/course/data-science-saude-e-medicina

# %% [markdown]
# ### Importando as bibliotecas e os dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/12/21  6/13/21  6/14/21  \
# 0        0        0        0        0  ...    88740    89861    91458
# 1        0        0        0        0  ...   132449   132459   132461
# 2        0        0        0        0  ...   133070   133388   133742
# 3        0        0        0        0  ...    13813    13813    13826
# 4        0        0        0        0  ...    36600    36705    36790
#
#    6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21  6/21/21
# 0    93272    93288    96531    98734    98734    98734   103902
# 1   132469   132476   132481   132484   132488   132490   132490
# 2   134115   134458   134840   135219   135586   135821   136294
# 3    13828    13836    13839    13842    13842    13842    13864
# 4    36921    37094    37289    37467    37604    37678    37748
#
# [5 rows x 521 columns]

# %%
# Como alguns países separaram os dados de covid por regiões e outros não, esses dados estão errados, para resolver isso
# agruparemos esses dados por países
confirmed['Country/Region'].value_counts()
# Out:
# China                  34
# Canada                 16
# United Kingdom         12
# France                 12
# Australia               8
#                        ..
# Libya                   1
# Micronesia              1
# Uganda                  1
# Japan                   1
# Antigua and Barbuda     1
# Name: Country/Region, Length: 194, dtype: int64

# %%
confirmed_by_country = confirmed.groupby('Country/Region').sum()
confirmed_by_country.head()
# Out:
#                      Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan     33.93911  67.709953        0        0        0        0
# Albania         41.15330  20.168300        0        0        0        0
# Algeria         28.03390   1.659600        0        0        0        0
# Andorra         42.50630   1.521800        0        0        0        0
# Angola         -11.20270  17.873900        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  6/12/21  6/13/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    88740    89861
# Albania               0        0        0        0  ...   132449   132459
# Algeria               0        0        0        0  ...   133070   133388
# Andorra               0        0        0        0  ...    13813    13813
# Angola                0        0        0        0  ...    36600    36705
#
#                 6/14/21  6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21  \
# Country/Region
# Afghanistan       91458    93272    93288    96531    98734    98734    98734
# Albania          132461   132469   132476   132481   132484   132488   132490
# Algeria          133742   134115   134458   134840   135219   135586   135821
# Andorra           13826    13828    13836    13839    13842    13842    13842
# Angola            36790    36921    37094    37289    37467    37604    37678
#
#                 6/21/21
# Country/Region
# Afghanistan      103902
# Albania          132490
# Algeria          136294
# Andorra           13864
# Angola            37748
#
# [5 rows x 519 columns]

# %%
last_date = confirmed_by_country.columns[-1]
last_date
# Out:
# '6/21/21'

# %%
confirmed_by_country.shape
# Out:
# (194, 519)

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
# ax.set_ylim([0, 20000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
# ax.set_ylim([0, 20000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(26,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:30].plot()
ax.set_ylim([0, 80000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados na China', fontsize=18)

confirmed_by_country.loc['China'][2:30].plot()
ax.set_ylim([20000, 60000])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].plot()
plt.show()

# %%
confirmed_by_country.loc['Brazil'][2:].diff().tail(20)
# Out:
# 6/2/21     95601.0
# 6/3/21     83391.0
# 6/4/21     37936.0
# 6/5/21     66017.0
# 6/6/21     39637.0
# 6/7/21     37156.0
# 6/8/21     52911.0
# 6/9/21     85748.0
# 6/10/21    88092.0
# 6/11/21    85149.0
# 6/12/21    78700.0
# 6/13/21    37948.0
# 6/14/21    39846.0
# 6/15/21    80609.0
# 6/16/21    95367.0
# 6/17/21    74042.0
# 6/18/21    98832.0
# 6/19/21    82288.0
# 6/20/21    44178.0
# 6/21/21    38903.0
# Name: Brazil, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Diferença de casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().plot()
plt.show()

# %%
confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().dropna()
# Out:
# 1/29/20        0.000000
# 1/30/20        0.000000
# 1/31/20        0.000000
# 2/1/20         0.000000
# 2/2/20         0.000000
#                ...
# 6/17/21    70237.285714
# 6/18/21    72192.000000
# 6/19/21    72704.571429
# 6/20/21    73594.571429
# 6/21/21    73459.857143
# Name: Brazil, Length: 510, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Média movel dos casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().dropna().plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Casos confirmados no Brasil', fontsize=18)

confirmed_by_country.loc['Brazil'][2:].diff().rolling(7).mean().plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Confirmados por país', fontsize=18)

confirmed_by_country[last_date].plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Casos confirmados', fontsize=14)
ax.set_title('Confirmados por país', fontsize=18)

confirmed_by_country[last_date].sort_values(ascending=False)[0:10].plot(kind='bar')
plt.show()

# %%
display(deaths.head())
display(recovered.head())
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/12/21  6/13/21  6/14/21  \
# 0        0        0        0        0  ...     3449     3527     3612
# 1        0        0        0        0  ...     2453     2453     2453
# 2        0        0        0        0  ...     3565     3571     3579
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      825      831      836
#
#    6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21  6/21/21
# 0     3683     3683     3842     3934     3934     3934     4215
# 1     2454     2454     2454     2454     2454     2454     2454
# 2     3588     3598     3605     3615     3624     3631     3641
# 3      127      127      127      127      127      127      127
# 4      842      847      851      853      856      859      868
#
# [5 rows x 521 columns]
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/12/21  6/13/21  6/14/21  \
# 0        0        0        0        0  ...    60939    61410    61706
# 1        0        0        0        0  ...   129826   129842   129865
# 2        0        0        0        0  ...    92620    92852    93094
# 3        0        0        0        0  ...    13591    13591    13618
# 4        0        0        0        0  ...    30207    30282    30359
#
#    6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21  6/21/21
# 0    61820    62397    62698    63426    63875    64401    65071
# 1   129879   129888   129895   129903   129910   129918   129918
# 2    93355    93586    93831    94093    94336    94571    94822
# 3    13626    13633    13640    13650    13650    13650    13665
# 4    30775    31003    31105    31569    31589    31676    31782
#
# [5 rows x 521 columns]

# %%
def lastest_by_country(data):
    return data.groupby('Country/Region').sum().iloc[:, -1]

# %%
lastest_by_country(confirmed).head()
# Out:
# Country/Region
# Afghanistan    103902
# Albania        132490
# Algeria        136294
# Andorra         13864
# Angola          37748
# Name: 6/21/21, dtype: int64

# %%
informations = [lastest_by_country(confirmed), lastest_by_country(deaths), lastest_by_country(recovered)]

# %%
combined = pd.concat(informations, axis=1)
combined.columns = ['confirmed', 'deaths', 'recovered']
combined
# Out:
#                     confirmed  deaths  recovered
# Country/Region
# Afghanistan            103902    4215      65071
# Albania                132490    2454     129918
# Algeria                136294    3641      94822
# Andorra                 13864     127      13665
# Angola                  37748     868      31782
# ...                       ...     ...        ...
# Vietnam                 13530      69       5453
# West Bank and Gaza     312811    3554     306312
# Yemen                    6889    1355       3958
# Zambia                 130631    1691     110450
# Zimbabwe                42195    1685      37200
#
# [194 rows x 3 columns]

# %%
sum_up = combined.sum()
letality_rate = sum_up['deaths'] / sum_up['confirmed']
print(f'A taxa de letalidade no conjunto de dados é: {letality_rate:0.2%}')
# Out:
# A taxa de letalidade no conjunto de dados é: 2.17%

# %%
letality_rate_1 = combined['deaths'] / combined['confirmed'] * 100
combined['letality_rate_1'] = letality_rate_1
combined['letality_rate_2'] = combined['deaths'] / (combined['deaths'] + combined['recovered']) * 100
combined.head()
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# Afghanistan        103902    4215      65071         4.056707         6.083480
# Albania            132490    2454     129918         1.852215         1.853866
# Algeria            136294    3641      94822         2.671431         3.697836
# Andorra             13864     127      13665         0.916042         0.920824
# Angola              37748     868      31782         2.299460         2.658499

# %%
combined.sort_values('letality_rate_1', ascending=False).head(20)
# Out:
#                         confirmed  deaths  recovered  letality_rate_1  \
# Country/Region
# Vanuatu                         4       1          3        25.000000
# MS Zaandam                      9       2          7        22.222222
# Yemen                        6889    1355       3958        19.669038
# Peru                      2030611  190645    1988382         9.388553
# Mexico                    2478551  231244    1974255         9.329806
# Sudan                       36347    2737      30062         7.530195
# Syria                       25158    1848      21747         7.345576
# Egypt                      277797   15898     206053         5.722884
# Somalia                     14867     775       7204         5.212888
# Ecuador                    446633   21304     415508         4.769912
# Bosnia and Herzegovina     204860    9643     180245         4.707117
# China                      103571    4846      98148         4.678916
# Bulgaria                   421152   18000     393186         4.273991
# Tanzania                      509      21        183         4.125737
# Afghanistan                103902    4215      65071         4.056707
# Taiwan*                     14080     569       7534         4.041193
# Zimbabwe                    42195    1685      37200         3.993364
# Bolivia                    422811   16174     340959         3.825350
# Comoros                      3912     146       3745         3.732106
# Hungary                    807630   29959     735574         3.709496
#
#                         letality_rate_2
# Country/Region
# Vanuatu                       25.000000
# MS Zaandam                    22.222222
# Yemen                         25.503482
# Peru                           8.749088
# Mexico                        10.484883
# Sudan                          8.344767
# Syria                          7.832168
# Egypt                          7.162842
# Somalia                        9.712997
# Ecuador                        4.877155
# Bosnia and Herzegovina         5.078257
# China                          4.705128
# Bulgaria                       4.377581
# Tanzania                      10.294118
# Afghanistan                    6.083480
# Taiwan*                        7.022091
# Zimbabwe                       4.333290
# Bolivia                        4.528845
# Comoros                        3.752249
# Hungary                        3.913483

# %%
# Como os países não estão reportando os números de recuperados adequadamente, o cálculo de letality rate está impreciso
combined.sort_values('letality_rate_2', ascending=False).head(20)
# Out:
#                 confirmed  deaths  recovered  letality_rate_1  letality_rate_2
# Country/Region
# Belgium           1079640   25141          0         2.328647       100.000000
# US               33554275  602092          0         1.794382       100.000000
# Serbia             715841    7004          0         0.978430       100.000000
# Sweden            1084636   14574          0         1.343677       100.000000
# United Kingdom    4656536  128245      15612         2.754086        89.147556
# Netherlands       1707181   18008      27225         1.054838        39.811642
# Spain             3764651   80689     150376         2.143333        34.920477
# Yemen                6889    1355       3958        19.669038        25.503482
# Vanuatu                 4       1          3        25.000000        25.000000
# MS Zaandam              9       2          7        22.222222        22.222222
# France            5819584  110940     402465         1.906322        21.608672
# Ireland            269321    4979      23364         1.848723        17.566948
# Greece             418548   12559      93764         3.000612        11.812120
# Mexico            2478551  231244    1974255         9.329806        10.484883
# Tanzania              509      21        183         4.125737        10.294118
# Somalia             14867     775       7204         5.212888         9.712997
# Peru              2030611  190645    1988382         9.388553         8.749088
# Sudan               36347    2737      30062         7.530195         8.344767
# Syria               25158    1848      21747         7.345576         7.832168
# Egypt              277797   15898     206053         5.722884         7.162842

# %%
combined[['confirmed', 'letality_rate_1']]
# Out:
#                     confirmed  letality_rate_1
# Country/Region
# Afghanistan            103902         4.056707
# Albania                132490         1.852215
# Algeria                136294         2.671431
# Andorra                 13864         0.916042
# Angola                  37748         2.299460
# ...                       ...              ...
# Vietnam                 13530         0.509978
# West Bank and Gaza     312811         1.136149
# Yemen                    6889        19.669038
# Zambia                 130631         1.294486
# Zimbabwe                42195         3.993364
#
# [194 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(14,8))

sns.scatterplot(x='confirmed', y='letality_rate_1', data=combined.query('recovered > 1e6'), ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,8))

sns.scatterplot(x='confirmed', y='letality_rate_2', data=combined.query('recovered > 1e6'), ax=ax)
plt.show()

# %%
sns.displot(data=combined.query('recovered > 1e3')['letality_rate_1'], aspect=2)
plt.show()

# %%
sns.displot(data=combined.query('recovered > 1e3')['letality_rate_2'], aspect=2)
plt.show()

# %%
def letality_rate_at(data):
    confirmed_at = confirmed.groupby('Country/Region').sum().loc[:, data]
    deaths_at = deaths.groupby('Country/Region').sum().loc[:, data]
    letality_rate = deaths_at.sum() / confirmed_at.sum()
    return letality_rate

# %%
datas = ['1/30/20', '2/28/20', '3/30/20', '4/30/20', '5/30/20', '6/30/20', '7/30/20', '8/30/20',
         '9/30/20', '10/30/20', '11/30/20', '12/30/20', '1/30/21', '2/28/21', '3/30/21', '4/30/21',
         '5/30/21', confirmed.columns[-1]]
litality_rate_months = []
for i in datas:
    litality_rate_months.append(letality_rate_at(i))
litality_rate_months
# Out:
# [0.020765027322404372,
#  0.03415277810798602,
#  0.04990306014526584,
#  0.07354109151553308,
#  0.06381490515640376,
#  0.05129361402977322,
#  0.04077099358591167,
#  0.03531348684112805,
#  0.031304190745071916,
#  0.027201435899106906,
#  0.02405154959406076,
#  0.022541423644971713,
#  0.022311931730713757,
#  0.022855562728097852,
#  0.02257635011847556,
#  0.02170063433900734,
#  0.021458889113566828,
#  0.021664176913917723]

# %%
fig, ax = plt.subplots(figsize=(18,8))
sns.lineplot(x=datas, y=litality_rate_months, ax=ax)
ax.set_title('Evolução da taxa de letalidade ao longo do tempo', fontsize=18, pad=10)
ax.set_xlabel('Meses', fontsize=14)
ax.set_ylabel('taxa de letalidade', fontsize=14)
ax.tick_params(labelsize=12, labelrotation=45)
plt.show()

# %% [markdown]
# # Segunda parte
#
# Link: https://cursos.alura.com.br/course/data-science-visualizacao-saude-e-medicina

# %%
confirmed.set_index('Country/Region').loc['China'].sum().tail()
# Out:
# 6/17/21    103467
# 6/18/21    103501
# 6/19/21    103525
# 6/20/21    103543
# 6/21/21    103571
# dtype: object

# %%
is_brazil = confirmed['Country/Region'] == 'Brazil'
confirmed['is_brazil'] = is_brazil
confirmed.tail()
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 273            NaN             Vietnam  14.058324  108.277199        0
# 274            NaN  West Bank and Gaza  31.952200   35.233200        0
# 275            NaN               Yemen  15.552727   48.516388        0
# 276            NaN              Zambia -13.133897   27.849332        0
# 277            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/13/21  6/14/21  \
# 273        2        2        2        2        2  ...    10630    10881
# 274        0        0        0        0        0  ...   311534   311690
# 275        0        0        0        0        0  ...     6862     6863
# 276        0        0        0        0        0  ...   111746   113134
# 277        0        0        0        0        0  ...    39959    40077
#
#      6/15/21  6/16/21  6/17/21  6/18/21  6/19/21  6/20/21  6/21/21  is_brazil
# 273    11304    11794    12150    12508    12978    13258    13530      False
# 274   311948   312164   312334   312499   312605   312673   312811      False
# 275     6864     6867     6869     6875     6877     6885     6889      False
# 276   115824   118850   122244   125157   126973   129033   130631      False
# 277    40318    40556    40927    41335    41628    41779    42195      False
#
# [5 rows x 522 columns]

# %%
confirmed.groupby('is_brazil').sum()
# Out:
#                   Lat         Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# is_brazil
# False      5603.14445  6144.679214      557      655      941     1433
# True        -14.23500   -51.925300        0        0        0        0
#
#            1/26/20  1/27/20  1/28/20  1/29/20  ...    6/12/21    6/13/21  \
# is_brazil                                      ...
# False         2118     2927     5578     6167  ...  158286253  158551221
# True             0        0        0        0  ...   17374818   17412766
#
#              6/14/21    6/15/21    6/16/21    6/17/21    6/18/21    6/19/21  \
# is_brazil
# False      158819894  159110785  159413957  159732417  160039533  160304691
# True        17452612   17533221   17628588   17702630   17801462   17883750
#
#              6/20/21    6/21/21
# is_brazil
# False      160560837  160819329
# True        17927928   17966831
#
# [2 rows x 519 columns]

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_title('Relação entre o número de casos confirmados no Brasil e no mundo', fontsize=18)
labels = ['Outros países', 'Brasil']

ax.pie(confirmed.groupby('is_brazil').sum().iloc[:, -1], labels=labels, shadow=True, autopct='%1.1f%%', 
       textprops={'fontsize':14})
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_title('Relação entre o número de casos confirmados no Brasil e no mundo', fontsize=18)
ax.set_xlabel('.')
ax.set_ylabel('Casos Confirmados', fontsize=14)
ax = confirmed.groupby('is_brazil').sum().iloc[:, -1].plot(kind='bar', ax=ax)
ax.set_xticklabels(['Outros países', 'Brasil'], fontsize=14, fontdict={'rotation': '0'})

plt.show()
